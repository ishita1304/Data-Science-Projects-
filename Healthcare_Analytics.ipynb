# %% [markdown]
# Congratulations – you have been hired as Chief Data Scientist of MedCamp – a not for profit organization dedicated in making health conditions for working professionals better. MedCamp was started because the founders saw their family suffer due to bad work life balance and neglected health.
#
# MedCamp organizes health camps in several cities with low work life balance. They reach out to working people and ask them to register for these health camps. For those who attend, MedCamp provides them facility to undergo health checks or increase awareness by visiting various stalls (depending on the format of camp).
#
# MedCamp has conducted 65 such events over a period of 4 years and they see a high drop off between “Registration” and Number of people taking tests at the Camps. In last 4 years, they have stored data of ~110,000 registrations they have done.
#
# One of the huge costs in arranging these camps is the amount of inventory you need to carry. If you carry more than required inventory, you incur unnecessarily high costs. On the other hand, if you carry less than required inventory for conducting these medical checks, people end up having bad experience.
#
#
#
# ***The Process:
# MedCamp employees / volunteers reach out to people and drive registrations.
# During the camp, People who “ShowUp” either undergo the medical tests or visit stalls depending on the format of health camp.
#
#
# *** Other things to note:
# * Since this is a completely voluntary activity for the working professionals, MedCamp usually has little profile information about these people.
# * For a few camps, there was hardware failure, so some information about date and time of registration is lost.
# * MedCamp runs 3 formats of these camps. The first and second format provides people with an instantaneous health score. The third format provides information about several health issues through various awareness stalls.
#
# #### Favorable outcome:
# For the first 2 formats, a favourable outcome is defined as getting a health_score, while in the third format it is defined as visiting at least a stall.
# You need to predict the chances (probability) of having a favourable outcome.
#
#
# **** Data Description
# Train.zip contains the following 6 csvs alongside the data dictionary that contains definitions for each variable
#
# * Health_Camp_Detail.csv – File containing Health_Camp_Id, Camp_Start_Date, Camp_End_Date and Category details of each camp.
#
# * Train.csv – File containing registration details for all the test camps. This includes Patient_ID, Health_Camp_ID, Registration_Date and a few anonymized variables as on registration date.
#
# * Patient_Profile.csv – This file contains Patient profile details like Patient_ID, Online_Follower, Social media details, Income, Education, Age, First_Interaction_Date, City_Type and Employer_Category
#
# * First_Health_Camp_Attended.csv – This file contains details about people who attended health camp of first format. This includes Donation (amount) & Health_Score of the person.
#
# * Second_Health_Camp_Attended.csv - This file contains details about people who attended health camp of second format. This includes Health_Score of the person.
#
# * Third_Health_Camp_Attended.csv - This file contains details about people who attended health camp of third format. This includes Number_of_stall_visited & Last_Stall_Visited_Number.
#
#
# Test Set
#
# Test.csv – File containing registration details for all the test camps. This includes Patient_ID, Health_Camp_ID, Registration_Date and a few anonymized variables as on registration date.
#
#
#
# Train / Test split:
#
# Camps started on or before 31st March 2006 are considered in Train
# Test data is for all camps conducted on or after 1st April 2006.
#
#
# Sample Submission:
#
# Patient_ID: Unique Identifier for each patient. This ID is not sequential in nature and can not be used in modeling
#
# Health_Camp_ID: Unique Identifier for each camp. This ID is not sequential in nature and can not be used in modeling
#
# Outcome: Predicted probability of a favourable outcome

# %%
# importing the libraries

import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize']=[15, 6]

pd.set_option('display.max_columns', 50) # Displaying all the data

# %%
# Import the dataset
train = pd.read_csv("~/Downloads/Healthcare/Train.csv")
test = pd.read_csv("~/Downloads/Healthcare/test_l0Auv8Q.csv")

fhc = pd.read_csv("~/Downloads/Healthcare/First_Health_Camp_Attended.csv")
shc = pd.read_csv("~/Downloads/Healthcare/Second_Health_Camp_Attended.csv")
thc = pd.read_csv("~/Downloads/Healthcare/Third_Health_Camp_Attended.csv")
hcdetail = pd.read_csv("~/Downloads/Healthcare/Health_Camp_Detail.csv")
pp = pd.read_csv("~/Downloads/Healthcare/Patient_Profile.csv")

# %%
# Combine the Train and Test
combined = pd.concat([train, test], ignore_index = True)

# %%
combined.shape
# Out:
# (110527, 8)

# %%
thc.head(2)
# Out:
#    Patient_ID  Health_Camp_ID  Number_of_stall_visited  \
# 0      517875            6527                        3
# 1      504692            6578                        1
#
#    Last_Stall_Visited_Number
# 0                          1
# 1                          1

# %%
combined.head(2)
# Out:
#    Patient_ID  Health_Camp_ID Registration_Date  Var1  Var2  Var3  Var4  Var5
# 0      489652            6578         10-Sep-05     4     0     0     0     2
# 1      507246            6578         18-Aug-05    45     5     0     0     7

# %%
# merge fhc with combined
combined = pd.merge(left = combined, right = fhc, 
                    on = ["Patient_ID", "Health_Camp_ID"], 
                    how = "left")

# %%
# merge shc with combined
combined = pd.merge(left = combined, right = shc, 
                    on = ["Patient_ID", "Health_Camp_ID"], 
                    how = "left")

# %%
# merge thc with combined
combined = pd.merge(left = combined, right = thc, 
                    on = ["Patient_ID", "Health_Camp_ID"], 
                    how = "left")

# %%
# merge healthcamp detail with combined
combined = pd.merge(left = combined, right = hcdetail, 
                    on = "Health_Camp_ID", 
                    how = "left")

# %%
# merge Patient Profile detail with combined
combined = pd.merge(left = combined, right = pp, 
                    on = "Patient_ID", 
                    how = "left")

# %% [markdown]
# ### Feature Engineering

# %%
# code to convert string into date

combined["Registration_Date"]=pd.to_datetime(combined['Registration_Date'], 
                                             dayfirst = True)

combined["Registration_Month"]= combined.Registration_Date.dt.month
combined["Registration_Year"]= combined.Registration_Date.dt.year
combined["Registration_Day"]= combined.Registration_Date.dt.day

# %%
combined.Registration_Date.isnull().sum()
# Out:
# 334

# %%
# Camp Start and End Date

combined["Camp_Start_Month"]= pd.DatetimeIndex(combined.Camp_Start_Date).month
combined["Camp_Start_Year"]= pd.DatetimeIndex(combined.Camp_Start_Date).year
combined["Camp_Start_Day"]= pd.DatetimeIndex(combined.Camp_Start_Date).day

combined["Camp_End_Month"]= pd.DatetimeIndex(combined.Camp_End_Date).month
combined["Camp_End_Year"]= pd.DatetimeIndex(combined.Camp_End_Date).year
combined["Camp_End_Day"]= pd.DatetimeIndex(combined.Camp_End_Date).day

# %%
# Creating Online_Presence using Patient Profiling Data

combined["Online_Presence"] = combined["Online_Follower"]+
combined["LinkedIn_Shared"]+
combined["Twitter_Shared"]+combined["Facebook_Shared"]

# %%
# Dropping the columns above
combined.drop(["LinkedIn_Shared", "Twitter_Shared", "Online_Follower",
              "Facebook_Shared"], axis = 1, inplace = True)

# %%
del pp

# %%
combined.head()
# Out:
#    Patient_ID  Health_Camp_ID Registration_Date  Var1  Var2  Var3  Var4  Var5  \
# 0      489652            6578        2005-09-10     4     0     0     0     2
# 1      507246            6578        2005-08-18    45     5     0     0     7
# 2      523729            6534        2006-04-29     0     0     0     0     0
# 3      524931            6535        2004-02-07     0     0     0     0     0
# 4      521364            6529        2006-02-28    15     1     0     0     7
#
#    Donation  Health_Score  Unnamed: 4  Health Score  Number_of_stall_visited  \
# 0       NaN           NaN         NaN           NaN                      2.0
# 1       NaN           NaN         NaN           NaN                      NaN
# 2       NaN           NaN         NaN      0.402054                      NaN
# 3       NaN           NaN         NaN           NaN                      NaN
# 4       NaN           NaN         NaN      0.845597                      NaN
#
#    Last_Stall_Visited_Number Camp_Start_Date Camp_End_Date Category1  \
# 0                        1.0       16-Aug-05     14-Oct-05     Third
# 1                        NaN       16-Aug-05     14-Oct-05     Third
# 2                        NaN       17-Oct-05     07-Nov-07    Second
# 3                        NaN       01-Feb-04     18-Feb-04     First
# 4                        NaN       30-Mar-06     03-Apr-06    Second
#
#   Category2  Category3 Income Education_Score   Age First_Interaction  \
# 0         G          2   None            None  None         06-Dec-04
# 1         G          2      1              75    40         08-Sep-04
# 2         A          2   None            None  None         22-Jun-04
# 3         E          2   None            None  None         07-Feb-04
# 4         A          2      1              70    40         04-Jul-03
#
#   City_Type Employer_Category  Registration_Month  Registration_Year  \
# 0       NaN               NaN                 9.0             2005.0
# 1         C            Others                 8.0             2005.0
# 2       NaN               NaN                 4.0             2006.0
# 3         I               NaN                 2.0             2004.0
# 4         I        Technology                 2.0             2006.0
#
#    Registration_Day  Camp_Start_Month  Camp_Start_Year  Camp_Start_Day  \
# 0              10.0                 8             2005              16
# 1              18.0                 8             2005              16
# 2              29.0                10             2005              17
# 3               7.0                 2             2004               1
# 4              28.0                 3             2006              30
#
#    Camp_End_Month  Camp_End_Year  Camp_End_Day  Online_Presence
# 0              10           2005            14                0
# 1              10           2005            14                0
# 2              11           2007             7                0
# 3               2           2004            18                0
# 4               4           2006             3                1

# %%
# Camp Duration from CampEndDate - Camp Start Date

combined["Camp_Start_Date"]=  pd.to_datetime(combined.Camp_Start_Date, 
                                             dayfirst = True)

combined["Camp_End_Date"]=  pd.to_datetime(combined.Camp_End_Date, 
                                           dayfirst = True)

combined["Camp_Duration"] =(combined["Camp_End_Date"] - 
                            combined["Camp_Start_Date"]).dt.days

# %%
# Converting First Interaction Date into datetime format

combined["First_Interaction"]=pd.to_datetime(combined.First_Interaction, 
                                             dayfirst = True)

# Days_interaction_diff = registration date - first interaction
combined["Int_Days_Diff"] = (combined["Registration_Date"] - 
                             combined["First_Interaction"]).dt.days

# %%
combined.head()
# Out:
#    Patient_ID  Health_Camp_ID Registration_Date  Var1  Var2  Var3  Var4  Var5  \
# 0      489652            6578        2005-09-10     4     0     0     0     2
# 1      507246            6578        2005-08-18    45     5     0     0     7
# 2      523729            6534        2006-04-29     0     0     0     0     0
# 3      524931            6535        2004-02-07     0     0     0     0     0
# 4      521364            6529        2006-02-28    15     1     0     0     7
#
#    Donation  Health_Score  Unnamed: 4  Health Score  Number_of_stall_visited  \
# 0       NaN           NaN         NaN           NaN                      2.0
# 1       NaN           NaN         NaN           NaN                      NaN
# 2       NaN           NaN         NaN      0.402054                      NaN
# 3       NaN           NaN         NaN           NaN                      NaN
# 4       NaN           NaN         NaN      0.845597                      NaN
#
#    Last_Stall_Visited_Number Camp_Start_Date Camp_End_Date Category1  \
# 0                        1.0      2005-08-16    2005-10-14     Third
# 1                        NaN      2005-08-16    2005-10-14     Third
# 2                        NaN      2005-10-17    2007-11-07    Second
# 3                        NaN      2004-02-01    2004-02-18     First
# 4                        NaN      2006-03-30    2006-04-03    Second
#
#   Category2  Category3 Income Education_Score   Age First_Interaction  \
# 0         G          2   None            None  None        2004-12-06
# 1         G          2      1              75    40        2004-09-08
# 2         A          2   None            None  None        2004-06-22
# 3         E          2   None            None  None        2004-02-07
# 4         A          2      1              70    40        2003-07-04
#
#   City_Type Employer_Category  Registration_Month  Registration_Year  \
# 0       NaN               NaN                 9.0             2005.0
# 1         C            Others                 8.0             2005.0
# 2       NaN               NaN                 4.0             2006.0
# 3         I               NaN                 2.0             2004.0
# 4         I        Technology                 2.0             2006.0
#
#    Registration_Day  Camp_Start_Month  Camp_Start_Year  Camp_Start_Day  \
# 0              10.0                 8             2005              16
# 1              18.0                 8             2005              16
# 2              29.0                10             2005              17
# 3               7.0                 2             2004               1
# 4              28.0                 3             2006              30
#
#    Camp_End_Month  Camp_End_Year  Camp_End_Day  Online_Presence  \
# 0              10           2005            14                0
# 1              10           2005            14                0
# 2              11           2007             7                0
# 3               2           2004            18                0
# 4               4           2006             3                1
#
#    Camp_Duration  Int_Days_Diff
# 0             59          278.0
# 1             59          344.0
# 2            751          676.0
# 3             17            0.0
# 4              4          970.0

# %%
# Donation vs Healthcamp
combined.groupby("Health_Camp_ID")["Donation"].describe()
# Out:
#                 count       mean        std   min   25%   50%   75%    max
# Health_Camp_ID
# 6523              0.0        NaN        NaN   NaN   NaN   NaN   NaN    NaN
# 6524             54.0  25.555556  10.580628  10.0  20.0  20.0  30.0   60.0
# 6525              0.0        NaN        NaN   NaN   NaN   NaN   NaN    NaN
# 6526            140.0  31.214286  24.034384  10.0  10.0  20.0  40.0  150.0
# 6527              0.0        NaN        NaN   NaN   NaN   NaN   NaN    NaN
# ...               ...        ...        ...   ...   ...   ...   ...    ...
# 6583              0.0        NaN        NaN   NaN   NaN   NaN   NaN    NaN
# 6584              0.0        NaN        NaN   NaN   NaN   NaN   NaN    NaN
# 6585            203.0  40.985222  26.921499  10.0  20.0  30.0  50.0  140.0
# 6586            600.0  30.683333  19.527808  10.0  20.0  30.0  40.0  140.0
# 6587             36.0  17.777778   7.968191  10.0  10.0  20.0  20.0   40.0
#
# [65 rows x 8 columns]

# %%
combined.Health_Camp_ID.nunique()
# Out:
# 65

# %%
# Unique Patient Per HC

combined["HC_per_patient"]= combined.groupby("Patient_ID")
["Health_Camp_ID"].transform('nunique')
combined["Patient_Per_HC"]= combined.groupby("Health_Camp_ID")
["Patient_ID"].transform('nunique')

# %%
# Lets Check the Desc Stats
combined.HC_per_patient.describe()
# Out:
# count    110527.000000
# mean          7.501036
# std           6.888289
# min           1.000000
# 25%           2.000000
# 50%           5.000000
# 75%          11.000000
# max          40.000000
# Name: HC_per_patient, dtype: float64

# %%
combined.Patient_Per_HC.describe()
# Out:
# count    110527.000000
# mean       2904.425480
# std        1330.060994
# min          44.000000
# 25%        1993.000000
# 50%        2763.000000
# 75%        3809.000000
# max        6543.000000
# Name: Patient_Per_HC, dtype: float64

# %%
# Unique Patients visited in beginning of the year camp started
combined.groupby("Camp_Start_Year")["Patient_ID"].transform('nunique')
# Out:
# 0         22359
# 1         22359
# 2         22359
# 3         10902
# 4         16175
#           ...
# 110522    16175
# 110523    16175
# 110524    16175
# 110525     2579
# 110526    16175
# Name: Patient_ID, Length: 110527, dtype: int64

# %%
combined["Patients_Per_Year"]= combined.groupby("Camp_Start_Year")
["Patient_ID"].transform('nunique')

combined.groupby("Camp_Start_Year")["Patient_ID"].nunique()
# Out:
# Camp_Start_Year
# 2003     3081
# 2004    10902
# 2005    22359
# 2006    16175
# 2007     2579
# Name: Patient_ID, dtype: int64

# %%
combined["Patients_Per_Month"]= combined.groupby("Camp_Start_Month")
["Patient_ID"].transform('nunique')

combined.groupby("Camp_Start_Month")["Patient_ID"].nunique()
# Out:
# Camp_Start_Month
# 1      9076
# 2      8717
# 3      3823
# 4      6164
# 5      1903
# 6      8208
# 7      3726
# 8     10445
# 9     11210
# 10     8242
# 11     8757
# 12     6774
# Name: Patient_ID, dtype: int64

# %%
combined["Patients_Per_End_Year"]= combined.groupby("Camp_End_Year")
["Patient_ID"].transform('nunique')

combined["Patients_Per_End_Month"]= combined.groupby("Camp_End_Month")
["Patient_ID"].transform('nunique')

# %%
combined.groupby("Camp_Start_Year")["Patient_ID"].nunique()
# Out:
# Camp_Start_Year
# 2003     3081
# 2004    10902
# 2005    22359
# 2006    16175
# 2007     2579
# Name: Patient_ID, dtype: int64

# %%
combined.groupby("Camp_End_Year")["Patient_ID"].nunique()
# Out:
# Camp_End_Year
# 2003     1753
# 2004     6319
# 2005    17330
# 2006    14842
# 2007    14379
# Name: Patient_ID, dtype: int64

# %%
combined.head()
# Out:
#    Patient_ID  Health_Camp_ID Registration_Date  Var1  Var2  Var3  Var4  Var5  \
# 0      489652            6578        2005-09-10     4     0     0     0     2
# 1      507246            6578        2005-08-18    45     5     0     0     7
# 2      523729            6534        2006-04-29     0     0     0     0     0
# 3      524931            6535        2004-02-07     0     0     0     0     0
# 4      521364            6529        2006-02-28    15     1     0     0     7
#
#    Donation  Health_Score  Unnamed: 4  Health Score  Number_of_stall_visited  \
# 0       NaN           NaN         NaN           NaN                      2.0
# 1       NaN           NaN         NaN           NaN                      NaN
# 2       NaN           NaN         NaN      0.402054                      NaN
# 3       NaN           NaN         NaN           NaN                      NaN
# 4       NaN           NaN         NaN      0.845597                      NaN
#
#    Last_Stall_Visited_Number Camp_Start_Date Camp_End_Date Category1  \
# 0                        1.0      2005-08-16    2005-10-14     Third
# 1                        NaN      2005-08-16    2005-10-14     Third
# 2                        NaN      2005-10-17    2007-11-07    Second
# 3                        NaN      2004-02-01    2004-02-18     First
# 4                        NaN      2006-03-30    2006-04-03    Second
#
#   Category2  Category3 Income Education_Score   Age First_Interaction  \
# 0         G          2   None            None  None        2004-12-06
# 1         G          2      1              75    40        2004-09-08
# 2         A          2   None            None  None        2004-06-22
# 3         E          2   None            None  None        2004-02-07
# 4         A          2      1              70    40        2003-07-04
#
#   City_Type Employer_Category  Registration_Month  Registration_Year  \
# 0       NaN               NaN                 9.0             2005.0
# 1         C            Others                 8.0             2005.0
# 2       NaN               NaN                 4.0             2006.0
# 3         I               NaN                 2.0             2004.0
# 4         I        Technology                 2.0             2006.0
#
#    Registration_Day  Camp_Start_Month  Camp_Start_Year  Camp_Start_Day  \
# 0              10.0                 8             2005              16
# 1              18.0                 8             2005              16
# 2              29.0                10             2005              17
# 3               7.0                 2             2004               1
# 4              28.0                 3             2006              30
#
#    Camp_End_Month  Camp_End_Year  Camp_End_Day  Online_Presence  \
# 0              10           2005            14                0
# 1              10           2005            14                0
# 2              11           2007             7                0
# 3               2           2004            18                0
# 4               4           2006             3                1
#
#    Camp_Duration  Int_Days_Diff  HC_per_patient  Patient_Per_HC  \
# 0             59          278.0              11            2837
# 1             59          344.0              26            2837
# 2            751          676.0               7            3597
# 3             17            0.0               6            1882
# 4              4          970.0              23            3823
#
#    Patients_Per_Year  Patients_Per_Month  Patients_Per_End_Year  \
# 0              22359               10445                  17330
# 1              22359               10445                  17330
# 2              22359                8242                  14379
# 3              10902                8717                   6319
# 4              16175                3823                  14842
#
#    Patients_Per_End_Month
# 0                    6109
# 1                    6109
# 2                   14643
# 3                   11010
# 4                    6519

# %% [markdown]
# ### Target Variable

# %%
def outcome(a, b, c, d):
    if((a>0) | (b>0) | (c>0) |(d>0)):
        return(1)
    else:
        return(0)

# %%
# generate the target variable...

combined["Target"] = combined.apply(lambda x:outcome(x["Health_Score"], 
                                x["Health Score"], 
                                x["Number_of_stall_visited"], 
                                x["Last_Stall_Visited_Number"]), axis = 1)

# %%
combined.Target.value_counts()
# Out:
# 0    89993
# 1    20534
# Name: Target, dtype: int64

# %%
print(combined.columns)
# Out:
# Index(['Patient_ID', 'Health_Camp_ID', 'Registration_Date', 'Var1', 'Var2',
#        'Var3', 'Var4', 'Var5', 'Donation', 'Health_Score', 'Unnamed: 4',
#        'Health Score', 'Number_of_stall_visited', 'Last_Stall_Visited_Number',
#        'Camp_Start_Date', 'Camp_End_Date', 'Category1', 'Category2',
#        'Category3', 'Income', 'Education_Score', 'Age', 'First_Interaction',
#        'City_Type', 'Employer_Category', 'Registration_Month',
#        'Registration_Year', 'Registration_Day', 'Camp_Start_Month',
#        'Camp_Start_Year', 'Camp_Start_Day', 'Camp_End_Month', 'Camp_End_Year',
#        'Camp_End_Day', 'Online_Presence', 'Camp_Duration', 'Int_Days_Diff',
#        'HC_per_patient', 'Patient_Per_HC', 'Patients_Per_Year',
#        'Patients_Per_Month', 'Patients_Per_End_Year', 'Patients_Per_End_Month',
#        'Target'],
#       dtype='object')

# %%
# Drop the Unnecessary Variables

new = combined.drop(['Patient_ID', 'Health_Camp_ID', 'Registration_Date',
                    'Donation', 'Health_Score', 'Unnamed: 4',
       'Health Score', 'Number_of_stall_visited', 
                     'Last_Stall_Visited_Number',
                    'Camp_Start_Date', 'Camp_End_Date','Income', 
                     'Education_Score',
                     'First_Interaction','City_Type', 
                     "Age", 'Employer_Category'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15108/206946401.py in <module>
#       1 # Drop the Unnecessary Variables
#       2
# ----> 3 new = combined.drop(['Patient_ID', 'Health_Camp_ID', 'Registration_Date',
#       4                     'Donation', 'Health_Score', 'Unnamed: 4',
#       5        'Health Score', 'Number_of_stall_visited',
#
# NameError: name 'combined' is not defined

# %%
del combined, fhc, shc, hcdetail, thc

# %%
new.shape
# Out:
# (110527, 27)

# %%
new.head()
# Out:
#    Var1  Var2  Var3  Var4  Var5 Category1 Category2  Category3  \
# 0     4     0     0     0     2     Third         G          2
# 1    45     5     0     0     7     Third         G          2
# 2     0     0     0     0     0    Second         A          2
# 3     0     0     0     0     0     First         E          2
# 4    15     1     0     0     7    Second         A          2
#
#    Registration_Month  Registration_Year  Registration_Day  Camp_Start_Month  \
# 0                 9.0             2005.0              10.0                 8
# 1                 8.0             2005.0              18.0                 8
# 2                 4.0             2006.0              29.0                10
# 3                 2.0             2004.0               7.0                 2
# 4                 2.0             2006.0              28.0                 3
#
#    Camp_Start_Year  Camp_Start_Day  Camp_End_Month  Camp_End_Year  \
# 0             2005              16              10           2005
# 1             2005              16              10           2005
# 2             2005              17              11           2007
# 3             2004               1               2           2004
# 4             2006              30               4           2006
#
#    Camp_End_Day  Online_Presence  Camp_Duration  Int_Days_Diff  \
# 0            14                0             59          278.0
# 1            14                0             59          344.0
# 2             7                0            751          676.0
# 3            18                0             17            0.0
# 4             3                1              4          970.0
#
#    HC_per_patient  Patient_Per_HC  Patients_Per_Year  Patients_Per_Month  \
# 0              11            2837              22359               10445
# 1              26            2837              22359               10445
# 2               7            3597              22359                8242
# 3               6            1882              10902                8717
# 4              23            3823              16175                3823
#
#    Patients_Per_End_Year  Patients_Per_End_Month  Target
# 0                  17330                    6109       1
# 1                  17330                    6109       0
# 2                  14379                   14643       1
# 3                   6319                   11010       0
# 4                  14842                    6519       1

# %%
new.Category2.value_counts()
# Out:
# E    28488
# F    28115
# G    21327
# A    19041
# D     8742
# B     2426
# C     2388
# Name: Category2, dtype: int64

# %%
mapped = {"First":1, "Second":2, "Third":3}
new["Category1"] = new.Category1.map(mapped)

# %%
# Category 2
new["Categor2"] = pd.factorize(new.Category2, sort = True)[0]

# %%
new.drop(["Category2"], axis = 1, inplace = True)

# %%
new.shape
# Out:
# (110527, 27)

# %%
new.isnull().sum()
# Out:
# Var1                        0
# Var2                        0
# Var3                        0
# Var4                        0
# Var5                        0
# Category1                   0
# Category3                   0
# Registration_Month        334
# Registration_Year         334
# Registration_Day          334
# Camp_Start_Month            0
# Camp_Start_Year             0
# Camp_Start_Day              0
# Camp_End_Month              0
# Camp_End_Year               0
# Camp_End_Day                0
# Online_Presence             0
# Camp_Duration               0
# Int_Days_Diff             334
# HC_per_patient              0
# Patient_Per_HC              0
# Patients_Per_Year           0
# Patients_Per_Month          0
# Patients_Per_End_Year       0
# Patients_Per_End_Month      0
# Target                      0
# Categor2                    0
# dtype: int64

# %%
new["Registration_Year"].fillna(new.Registration_Year.mode()[0],
                               inplace = True)

# %%
new["Registration_Month"].fillna(new.Registration_Month.mode()[0],
                                 inplace = True)

# %%
new["Registration_Day"].fillna(new.Registration_Day.mode()[0],
                                 inplace = True)

# %%
new["Int_Days_Diff"].fillna(new.Int_Days_Diff.median(),
                                 inplace = True)

# %%
new.isnull().sum()
# Out:
# Var1                      0
# Var2                      0
# Var3                      0
# Var4                      0
# Var5                      0
# Category1                 0
# Category3                 0
# Registration_Month        0
# Registration_Year         0
# Registration_Day          0
# Camp_Start_Month          0
# Camp_Start_Year           0
# Camp_Start_Day            0
# Camp_End_Month            0
# Camp_End_Year             0
# Camp_End_Day              0
# Online_Presence           0
# Camp_Duration             0
# Int_Days_Diff             0
# HC_per_patient            0
# Patient_Per_HC            0
# Patients_Per_Year         0
# Patients_Per_Month        0
# Patients_Per_End_Year     0
# Patients_Per_End_Month    0
# Target                    0
# Categor2                  0
# dtype: int64

# %% [markdown]
# ### Split the Data back in Train and Test and delete target in Test

# %%
train.shape, test.shape
# Out:
# ((75278, 8), (35249, 8))

# %%
newtrain = new.loc[0:train.shape[0]-1, :]
newtest = new.loc[train.shape[0]:, :]

# %%
newtrain.shape, newtest.shape
# Out:
# ((75278, 27), (35249, 27))

# %%
# Drop Target from test
newtest.drop("Target", axis =1, inplace = True)

# %%
newtrain.shape, newtest.shape
# Out:
# ((75278, 27), (35249, 26))

# %% [markdown]
# ### Model Building
#
# 1. Logistic Regression Model
# 2. Random Forest Model
# 3. Gradient Boosting Model
# 4. Xtreme Gradient Boosting Model
# 5. Catboost Model

# %%
# Data in X and y
X = newtrain.drop("Target", axis = 1)
y = newtrain.Target

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier

# %%
# Models
lr = LogisticRegression()
rf = RandomForestClassifier()
gbm = GradientBoostingClassifier()
xgb = XGBClassifier(eval_metric = "auc")
cboost = CatBoostClassifier(eval_metric = "AUC")

# %%
# Lets Build a Voting Classifier Model
from sklearn.ensemble import VotingClassifier
vc=VotingClassifier(estimators=[('lr', lr), ('rf', rf), 
                                ('gbm', gbm), ('xgb', xgb), 
                                ('cb', cboost)], voting = "soft")

# %%
pred = vc.fit(X, y).predict_proba(newtest)
# Out:
# Learning rate set to 0.065204
# 0:	total: 8.02ms	remaining: 8.01s
# 1:	total: 15.4ms	remaining: 7.67s
# 2:	total: 23.8ms	remaining: 7.89s
# 3:	total: 31.3ms	remaining: 7.79s
# 4:	total: 38.5ms	remaining: 7.66s
# 5:	total: 57.6ms	remaining: 9.54s
# 6:	total: 65.3ms	remaining: 9.26s
# 7:	total: 72.9ms	remaining: 9.04s
# 8:	total: 80.6ms	remaining: 8.88s
# 9:	total: 88.2ms	remaining: 8.73s
# 10:	total: 95.9ms	remaining: 8.62s
# 11:	total: 107ms	remaining: 8.84s
# 12:	total: 116ms	remaining: 8.79s
# 13:	total: 123ms	remaining: 8.66s
# 14:	total: 138ms	remaining: 9.06s
# 15:	total: 148ms	remaining: 9.1s
# 16:	total: 156ms	remaining: 9s
# 17:	total: 163ms	remaining: 8.9s
# 18:	total: 171ms	remaining: 8.8s
# 19:	total: 178ms	remaining: 8.71s
# 20:	total: 193ms	remaining: 9.02s
# 21:	total: 206ms	remaining: 9.15s
# 22:	total: 213ms	remaining: 9.07s
# 23:	total: 232ms	remaining: 9.45s
# 24:	total: 240ms	remaining: 9.36s
# 25:	total: 249ms	remaining: 9.32s
# 26:	total: 258ms	remaining: 9.29s
# 27:	total: 266ms	remaining: 9.23s
# 28:	total: 274ms	remaining: 9.18s
# 29:	total: 281ms	remaining: 9.1s
# 30:	total: 288ms	remaining: 9.01s
# 31:	total: 296ms	remaining: 8.94s
# 32:	total: 303ms	remaining: 8.87s
# 33:	total: 321ms	remaining: 9.11s
# 34:	total: 328ms	remaining: 9.03s
# 35:	total: 335ms	remaining: 8.97s
# 36:	total: 349ms	remaining: 9.08s
# 37:	total: 356ms	remaining: 9.01s
# 38:	total: 363ms	remaining: 8.95s
# 39:	total: 371ms	remaining: 8.9s
# 40:	total: 393ms	remaining: 9.2s
# 41:	total: 414ms	remaining: 9.45s
# 42:	total: 422ms	remaining: 9.39s
# 43:	total: 429ms	remaining: 9.31s
# 44:	total: 437ms	remaining: 9.27s
# 45:	total: 445ms	remaining: 9.22s
# 46:	total: 453ms	remaining: 9.19s
# 47:	total: 460ms	remaining: 9.12s
# 48:	total: 468ms	remaining: 9.07s
# 49:	total: 475ms	remaining: 9.03s
# 50:	total: 483ms	remaining: 8.98s
# 51:	total: 502ms	remaining: 9.15s
# 52:	total: 509ms	remaining: 9.1s
# 53:	total: 518ms	remaining: 9.07s
# 54:	total: 527ms	remaining: 9.05s
# 55:	total: 535ms	remaining: 9.03s
# 56:	total: 544ms	remaining: 8.99s
# 57:	total: 551ms	remaining: 8.95s
# 58:	total: 558ms	remaining: 8.9s
# 59:	total: 566ms	remaining: 8.86s
# 60:	total: 573ms	remaining: 8.81s
# 61:	total: 600ms	remaining: 9.07s
# 62:	total: 608ms	remaining: 9.04s
# 63:	total: 616ms	remaining: 9.01s
# 64:	total: 625ms	remaining: 8.98s
# 65:	total: 633ms	remaining: 8.96s
# 66:	total: 646ms	remaining: 9s
# 67:	total: 653ms	remaining: 8.96s
# 68:	total: 683ms	remaining: 9.22s
# 69:	total: 694ms	remaining: 9.21s
# 70:	total: 700ms	remaining: 9.16s
# 71:	total: 709ms	remaining: 9.14s
# 72:	total: 716ms	remaining: 9.1s
# 73:	total: 725ms	remaining: 9.07s
# 74:	total: 733ms	remaining: 9.04s
# 75:	total: 741ms	remaining: 9s
# 76:	total: 749ms	remaining: 8.98s
# 77:	total: 770ms	remaining: 9.1s
# 78:	total: 777ms	remaining: 9.06s
# 79:	total: 786ms	remaining: 9.04s
# 80:	total: 793ms	remaining: 8.99s
# 81:	total: 800ms	remaining: 8.96s
# 82:	total: 807ms	remaining: 8.91s
# 83:	total: 818ms	remaining: 8.92s
# 84:	total: 828ms	remaining: 8.91s
# 85:	total: 835ms	remaining: 8.88s
# 86:	total: 842ms	remaining: 8.84s
# 87:	total: 861ms	remaining: 8.92s
# 88:	total: 868ms	remaining: 8.88s
# 89:	total: 875ms	remaining: 8.85s
# 90:	total: 882ms	remaining: 8.81s
# 91:	total: 890ms	remaining: 8.78s
# 92:	total: 897ms	remaining: 8.74s
# 93:	total: 904ms	remaining: 8.71s
# 94:	total: 911ms	remaining: 8.68s
# 95:	total: 918ms	remaining: 8.64s
# 96:	total: 926ms	remaining: 8.62s
# 97:	total: 949ms	remaining: 8.74s
# 98:	total: 957ms	remaining: 8.71s
# 99:	total: 964ms	remaining: 8.68s
# 100:	total: 972ms	remaining: 8.65s
# 101:	total: 979ms	remaining: 8.62s
# 102:	total: 987ms	remaining: 8.59s
# 103:	total: 994ms	remaining: 8.56s
# 104:	total: 1s	remaining: 8.53s
# 105:	total: 1.01s	remaining: 8.51s
# 106:	total: 1.02s	remaining: 8.49s
# 107:	total: 1.04s	remaining: 8.57s
# 108:	total: 1.05s	remaining: 8.55s
# 109:	total: 1.06s	remaining: 8.57s
# 110:	total: 1.07s	remaining: 8.55s
# 111:	total: 1.07s	remaining: 8.52s
# 112:	total: 1.08s	remaining: 8.49s
# 113:	total: 1.09s	remaining: 8.46s
# 114:	total: 1.1s	remaining: 8.44s
# 115:	total: 1.1s	remaining: 8.41s
# 116:	total: 1.13s	remaining: 8.51s
# 117:	total: 1.14s	remaining: 8.49s
# 118:	total: 1.14s	remaining: 8.46s
# 119:	total: 1.15s	remaining: 8.43s
# 120:	total: 1.16s	remaining: 8.4s
# 121:	total: 1.16s	remaining: 8.38s
# 122:	total: 1.17s	remaining: 8.35s
# 123:	total: 1.18s	remaining: 8.32s
# 124:	total: 1.19s	remaining: 8.3s
# 125:	total: 1.19s	remaining: 8.28s
# 126:	total: 1.2s	remaining: 8.27s
# 127:	total: 1.22s	remaining: 8.3s
# 128:	total: 1.23s	remaining: 8.27s
# 129:	total: 1.23s	remaining: 8.25s
# 130:	total: 1.24s	remaining: 8.22s
# 131:	total: 1.25s	remaining: 8.2s
# 132:	total: 1.25s	remaining: 8.17s
# 133:	total: 1.26s	remaining: 8.15s
# 134:	total: 1.27s	remaining: 8.12s
# 135:	total: 1.28s	remaining: 8.11s
# 136:	total: 1.29s	remaining: 8.11s
# 137:	total: 1.31s	remaining: 8.19s
# 138:	total: 1.32s	remaining: 8.16s
# 139:	total: 1.32s	remaining: 8.14s
# 140:	total: 1.33s	remaining: 8.12s
# 141:	total: 1.34s	remaining: 8.1s
# 142:	total: 1.35s	remaining: 8.07s
# 143:	total: 1.35s	remaining: 8.04s
# 144:	total: 1.36s	remaining: 8.02s
# 145:	total: 1.37s	remaining: 8s
# 146:	total: 1.37s	remaining: 7.97s
# 147:	total: 1.39s	remaining: 8.02s
# 148:	total: 1.4s	remaining: 7.99s
# 149:	total: 1.41s	remaining: 7.97s
# 150:	total: 1.41s	remaining: 7.95s
# 151:	total: 1.42s	remaining: 7.93s
# 152:	total: 1.43s	remaining: 7.91s
# 153:	total: 1.44s	remaining: 7.89s
# 154:	total: 1.44s	remaining: 7.87s
# 155:	total: 1.45s	remaining: 7.86s
# 156:	total: 1.46s	remaining: 7.84s
# 157:	total: 1.48s	remaining: 7.87s
# 158:	total: 1.49s	remaining: 7.87s
# 159:	total: 1.5s	remaining: 7.86s
# 160:	total: 1.5s	remaining: 7.84s
# 161:	total: 1.51s	remaining: 7.81s
# 162:	total: 1.52s	remaining: 7.79s
# 163:	total: 1.53s	remaining: 7.8s
# 164:	total: 1.54s	remaining: 7.79s
# 165:	total: 1.54s	remaining: 7.77s
# 166:	total: 1.55s	remaining: 7.75s
# 167:	total: 1.57s	remaining: 7.78s
# 168:	total: 1.58s	remaining: 7.76s
# 169:	total: 1.58s	remaining: 7.73s
# 170:	total: 1.59s	remaining: 7.71s
# 171:	total: 1.6s	remaining: 7.69s
# 172:	total: 1.61s	remaining: 7.68s
# 173:	total: 1.61s	remaining: 7.66s
# 174:	total: 1.62s	remaining: 7.64s
# 175:	total: 1.63s	remaining: 7.62s
# 176:	total: 1.64s	remaining: 7.61s
# 177:	total: 1.65s	remaining: 7.6s
# 178:	total: 1.66s	remaining: 7.63s
# 179:	total: 1.67s	remaining: 7.61s
# 180:	total: 1.68s	remaining: 7.59s
# 181:	total: 1.68s	remaining: 7.57s
# 182:	total: 1.69s	remaining: 7.55s
# 183:	total: 1.7s	remaining: 7.54s
# 184:	total: 1.71s	remaining: 7.52s
# 185:	total: 1.71s	remaining: 7.5s
# 186:	total: 1.72s	remaining: 7.48s
# 187:	total: 1.73s	remaining: 7.46s
# 188:	total: 1.74s	remaining: 7.48s
# 189:	total: 1.75s	remaining: 7.46s
# 190:	total: 1.76s	remaining: 7.46s
# 191:	total: 1.77s	remaining: 7.45s
# 192:	total: 1.78s	remaining: 7.43s
# 193:	total: 1.78s	remaining: 7.41s
# 194:	total: 1.79s	remaining: 7.39s
# 195:	total: 1.8s	remaining: 7.38s
# 196:	total: 1.8s	remaining: 7.36s
# 197:	total: 1.81s	remaining: 7.34s
# 198:	total: 1.83s	remaining: 7.37s
# 199:	total: 1.84s	remaining: 7.36s
# 200:	total: 1.85s	remaining: 7.34s
# 201:	total: 1.85s	remaining: 7.33s
# 202:	total: 1.86s	remaining: 7.31s
# 203:	total: 1.87s	remaining: 7.29s
# 204:	total: 1.88s	remaining: 7.27s
# 205:	total: 1.88s	remaining: 7.25s
# 206:	total: 1.89s	remaining: 7.24s
# 207:	total: 1.9s	remaining: 7.22s
# 208:	total: 1.9s	remaining: 7.21s
# 209:	total: 1.92s	remaining: 7.23s
# 210:	total: 1.93s	remaining: 7.22s
# 211:	total: 1.94s	remaining: 7.2s
# 212:	total: 1.95s	remaining: 7.19s
# 213:	total: 1.95s	remaining: 7.17s
# 214:	total: 1.96s	remaining: 7.15s
# 215:	total: 1.97s	remaining: 7.14s
# 216:	total: 1.97s	remaining: 7.12s
# 217:	total: 1.98s	remaining: 7.11s
# 218:	total: 1.99s	remaining: 7.09s
# 219:	total: 2.01s	remaining: 7.12s
# 220:	total: 2.02s	remaining: 7.13s
# 221:	total: 2.03s	remaining: 7.11s
# 222:	total: 2.04s	remaining: 7.09s
# 223:	total: 2.04s	remaining: 7.08s
# 224:	total: 2.05s	remaining: 7.06s
# 225:	total: 2.06s	remaining: 7.04s
# 226:	total: 2.06s	remaining: 7.03s
# 227:	total: 2.07s	remaining: 7.01s
# 228:	total: 2.08s	remaining: 7s
# 229:	total: 2.08s	remaining: 6.98s
# 230:	total: 2.1s	remaining: 7s
# 231:	total: 2.11s	remaining: 6.98s
# 232:	total: 2.12s	remaining: 6.97s
# 233:	total: 2.12s	remaining: 6.95s
# 234:	total: 2.13s	remaining: 6.94s
# 235:	total: 2.14s	remaining: 6.92s
# 236:	total: 2.15s	remaining: 6.91s
# 237:	total: 2.15s	remaining: 6.89s
# 238:	total: 2.16s	remaining: 6.88s
# 239:	total: 2.17s	remaining: 6.86s
# 240:	total: 2.17s	remaining: 6.85s
# 241:	total: 2.19s	remaining: 6.86s
# 242:	total: 2.2s	remaining: 6.85s
# 243:	total: 2.21s	remaining: 6.84s
# 244:	total: 2.21s	remaining: 6.83s
# 245:	total: 2.22s	remaining: 6.81s
# 246:	total: 2.24s	remaining: 6.82s
# 247:	total: 2.24s	remaining: 6.8s
# 248:	total: 2.25s	remaining: 6.79s
# 249:	total: 2.26s	remaining: 6.77s
# 250:	total: 2.28s	remaining: 6.79s
# 251:	total: 2.28s	remaining: 6.78s
# 252:	total: 2.29s	remaining: 6.76s
# 253:	total: 2.3s	remaining: 6.75s
# 254:	total: 2.3s	remaining: 6.73s
# 255:	total: 2.31s	remaining: 6.72s
# 256:	total: 2.32s	remaining: 6.7s
# 257:	total: 2.33s	remaining: 6.69s
# 258:	total: 2.33s	remaining: 6.67s
# 259:	total: 2.34s	remaining: 6.66s
# 260:	total: 2.35s	remaining: 6.64s
# 261:	total: 2.35s	remaining: 6.63s
# 262:	total: 2.36s	remaining: 6.62s
# 263:	total: 2.37s	remaining: 6.61s
# 264:	total: 2.38s	remaining: 6.59s
# 265:	total: 2.38s	remaining: 6.58s
# 266:	total: 2.39s	remaining: 6.57s
# 267:	total: 2.4s	remaining: 6.56s
# 268:	total: 2.41s	remaining: 6.54s
# 269:	total: 2.41s	remaining: 6.53s
# 270:	total: 2.42s	remaining: 6.51s
# 271:	total: 2.43s	remaining: 6.5s
# 272:	total: 2.44s	remaining: 6.49s
# 273:	total: 2.46s	remaining: 6.51s
# 274:	total: 2.47s	remaining: 6.5s
# 275:	total: 2.48s	remaining: 6.5s
# 276:	total: 2.48s	remaining: 6.49s
# 277:	total: 2.49s	remaining: 6.47s
# 278:	total: 2.5s	remaining: 6.46s
# 279:	total: 2.51s	remaining: 6.44s
# 280:	total: 2.51s	remaining: 6.43s
# 281:	total: 2.52s	remaining: 6.42s
# 282:	total: 2.53s	remaining: 6.41s
# 283:	total: 2.55s	remaining: 6.42s
# 284:	total: 2.56s	remaining: 6.41s
# 285:	total: 2.56s	remaining: 6.4s
# 286:	total: 2.57s	remaining: 6.38s
# 287:	total: 2.58s	remaining: 6.38s
# 288:	total: 2.58s	remaining: 6.36s
# 289:	total: 2.59s	remaining: 6.35s
# 290:	total: 2.6s	remaining: 6.34s
# 291:	total: 2.61s	remaining: 6.33s
# 292:	total: 2.62s	remaining: 6.32s
# 293:	total: 2.64s	remaining: 6.34s
# 294:	total: 2.65s	remaining: 6.33s
# 295:	total: 2.66s	remaining: 6.32s
# 296:	total: 2.66s	remaining: 6.31s
# 297:	total: 2.67s	remaining: 6.29s
# 298:	total: 2.68s	remaining: 6.28s
# 299:	total: 2.69s	remaining: 6.27s
# 300:	total: 2.69s	remaining: 6.25s
# 301:	total: 2.7s	remaining: 6.25s
# 302:	total: 2.73s	remaining: 6.27s
# 303:	total: 2.73s	remaining: 6.26s
# 304:	total: 2.74s	remaining: 6.24s
# 305:	total: 2.75s	remaining: 6.23s
# 306:	total: 2.76s	remaining: 6.22s
# 307:	total: 2.76s	remaining: 6.21s
# 308:	total: 2.77s	remaining: 6.2s
# 309:	total: 2.78s	remaining: 6.18s
# 310:	total: 2.78s	remaining: 6.17s
# 311:	total: 2.79s	remaining: 6.16s
# 312:	total: 2.81s	remaining: 6.17s
# 313:	total: 2.82s	remaining: 6.15s
# 314:	total: 2.82s	remaining: 6.14s
# 315:	total: 2.83s	remaining: 6.13s
# 316:	total: 2.84s	remaining: 6.12s
# 317:	total: 2.85s	remaining: 6.1s
# 318:	total: 2.85s	remaining: 6.09s
# 319:	total: 2.86s	remaining: 6.08s
# 320:	total: 2.87s	remaining: 6.06s
# 321:	total: 2.87s	remaining: 6.05s
# 322:	total: 2.88s	remaining: 6.04s
# 323:	total: 2.9s	remaining: 6.04s
# 324:	total: 2.9s	remaining: 6.03s
# 325:	total: 2.91s	remaining: 6.02s
# 326:	total: 2.92s	remaining: 6.01s
# 327:	total: 2.93s	remaining: 6s
# 328:	total: 2.94s	remaining: 6s
# 329:	total: 2.95s	remaining: 5.99s
# 330:	total: 2.96s	remaining: 5.98s
# 331:	total: 2.96s	remaining: 5.96s
# 332:	total: 2.97s	remaining: 5.95s
# 333:	total: 2.99s	remaining: 5.97s
# 334:	total: 3s	remaining: 5.96s
# 335:	total: 3.01s	remaining: 5.94s
# 336:	total: 3.02s	remaining: 5.93s
# 337:	total: 3.02s	remaining: 5.92s
# 338:	total: 3.03s	remaining: 5.91s
# 339:	total: 3.04s	remaining: 5.9s
# 340:	total: 3.04s	remaining: 5.88s
# 341:	total: 3.05s	remaining: 5.87s
# 342:	total: 3.06s	remaining: 5.86s
# 343:	total: 3.08s	remaining: 5.87s
# 344:	total: 3.08s	remaining: 5.86s
# 345:	total: 3.09s	remaining: 5.84s
# 346:	total: 3.1s	remaining: 5.83s
# 347:	total: 3.1s	remaining: 5.82s
# 348:	total: 3.11s	remaining: 5.81s
# 349:	total: 3.12s	remaining: 5.8s
# 350:	total: 3.13s	remaining: 5.79s
# 351:	total: 3.14s	remaining: 5.77s
# 352:	total: 3.14s	remaining: 5.76s
# 353:	total: 3.15s	remaining: 5.75s
# 354:	total: 3.17s	remaining: 5.76s
# 355:	total: 3.18s	remaining: 5.76s
# 356:	total: 3.19s	remaining: 5.75s
# 357:	total: 3.2s	remaining: 5.73s
# 358:	total: 3.2s	remaining: 5.72s
# 359:	total: 3.21s	remaining: 5.71s
# 360:	total: 3.22s	remaining: 5.7s
# 361:	total: 3.23s	remaining: 5.68s
# 362:	total: 3.23s	remaining: 5.67s
# 363:	total: 3.24s	remaining: 5.66s
# 364:	total: 3.26s	remaining: 5.67s
# 365:	total: 3.26s	remaining: 5.65s
# 366:	total: 3.27s	remaining: 5.64s
# 367:	total: 3.28s	remaining: 5.63s
# 368:	total: 3.28s	remaining: 5.62s
# 369:	total: 3.29s	remaining: 5.61s
# 370:	total: 3.3s	remaining: 5.59s
# 371:	total: 3.31s	remaining: 5.58s
# 372:	total: 3.31s	remaining: 5.57s
# 373:	total: 3.32s	remaining: 5.56s
# 374:	total: 3.33s	remaining: 5.55s
# 375:	total: 3.35s	remaining: 5.55s
# 376:	total: 3.35s	remaining: 5.54s
# 377:	total: 3.36s	remaining: 5.53s
# 378:	total: 3.37s	remaining: 5.52s
# 379:	total: 3.38s	remaining: 5.51s
# 380:	total: 3.38s	remaining: 5.5s
# 381:	total: 3.39s	remaining: 5.48s
# 382:	total: 3.4s	remaining: 5.47s
# 383:	total: 3.4s	remaining: 5.46s
# 384:	total: 3.41s	remaining: 5.45s
# 385:	total: 3.43s	remaining: 5.46s
# 386:	total: 3.44s	remaining: 5.45s
# 387:	total: 3.45s	remaining: 5.44s
# 388:	total: 3.46s	remaining: 5.43s
# 389:	total: 3.46s	remaining: 5.42s
# 390:	total: 3.47s	remaining: 5.41s
# 391:	total: 3.48s	remaining: 5.39s
# 392:	total: 3.48s	remaining: 5.38s
# 393:	total: 3.49s	remaining: 5.37s
# 394:	total: 3.5s	remaining: 5.36s
# 395:	total: 3.51s	remaining: 5.35s
# 396:	total: 3.52s	remaining: 5.35s
# 397:	total: 3.53s	remaining: 5.34s
# 398:	total: 3.54s	remaining: 5.33s
# 399:	total: 3.55s	remaining: 5.32s
# 400:	total: 3.55s	remaining: 5.31s
# 401:	total: 3.56s	remaining: 5.29s
# 402:	total: 3.57s	remaining: 5.28s
# 403:	total: 3.57s	remaining: 5.27s
# 404:	total: 3.58s	remaining: 5.26s
# 405:	total: 3.59s	remaining: 5.25s
# 406:	total: 3.59s	remaining: 5.24s
# 407:	total: 3.6s	remaining: 5.23s
# 408:	total: 3.61s	remaining: 5.21s
# 409:	total: 3.62s	remaining: 5.2s
# 410:	total: 3.62s	remaining: 5.19s
# 411:	total: 3.63s	remaining: 5.18s
# 412:	total: 3.64s	remaining: 5.17s
# 413:	total: 3.65s	remaining: 5.17s
# 414:	total: 3.66s	remaining: 5.16s
# 415:	total: 3.67s	remaining: 5.15s
# 416:	total: 3.67s	remaining: 5.14s
# 417:	total: 3.68s	remaining: 5.13s
# 418:	total: 3.7s	remaining: 5.13s
# 419:	total: 3.71s	remaining: 5.12s
# 420:	total: 3.71s	remaining: 5.11s
# 421:	total: 3.72s	remaining: 5.1s
# 422:	total: 3.73s	remaining: 5.09s
# 423:	total: 3.74s	remaining: 5.08s
# 424:	total: 3.74s	remaining: 5.06s
# 425:	total: 3.75s	remaining: 5.05s
# 426:	total: 3.76s	remaining: 5.04s
# 427:	total: 3.77s	remaining: 5.03s
# 428:	total: 3.77s	remaining: 5.03s
# 429:	total: 3.79s	remaining: 5.02s
# 430:	total: 3.79s	remaining: 5.01s
# 431:	total: 3.8s	remaining: 5s
# 432:	total: 3.81s	remaining: 4.99s
# 433:	total: 3.82s	remaining: 4.98s
# 434:	total: 3.82s	remaining: 4.97s
# 435:	total: 3.83s	remaining: 4.96s
# 436:	total: 3.84s	remaining: 4.95s
# 437:	total: 3.85s	remaining: 4.93s
# 438:	total: 3.85s	remaining: 4.92s
# 439:	total: 3.86s	remaining: 4.92s
# 440:	total: 3.88s	remaining: 4.92s
# 441:	total: 3.89s	remaining: 4.91s
# 442:	total: 3.9s	remaining: 4.9s
# 443:	total: 3.9s	remaining: 4.89s
# 444:	total: 3.91s	remaining: 4.88s
# 445:	total: 3.92s	remaining: 4.87s
# 446:	total: 3.93s	remaining: 4.86s
# 447:	total: 3.93s	remaining: 4.85s
# 448:	total: 3.94s	remaining: 4.84s
# 449:	total: 3.96s	remaining: 4.84s
# 450:	total: 3.97s	remaining: 4.83s
# 451:	total: 3.97s	remaining: 4.82s
# 452:	total: 3.98s	remaining: 4.81s
# 453:	total: 3.99s	remaining: 4.8s
# 454:	total: 4s	remaining: 4.79s
# 455:	total: 4s	remaining: 4.77s
# 456:	total: 4.01s	remaining: 4.76s
# 457:	total: 4.02s	remaining: 4.75s
# 458:	total: 4.03s	remaining: 4.75s
# 459:	total: 4.03s	remaining: 4.74s
# 460:	total: 4.05s	remaining: 4.74s
# 461:	total: 4.06s	remaining: 4.73s
# 462:	total: 4.07s	remaining: 4.72s
# 463:	total: 4.08s	remaining: 4.71s
# 464:	total: 4.08s	remaining: 4.7s
# 465:	total: 4.09s	remaining: 4.69s
# 466:	total: 4.1s	remaining: 4.68s
# 467:	total: 4.11s	remaining: 4.67s
# 468:	total: 4.12s	remaining: 4.67s
# 469:	total: 4.14s	remaining: 4.67s
# 470:	total: 4.14s	remaining: 4.66s
# 471:	total: 4.15s	remaining: 4.64s
# 472:	total: 4.16s	remaining: 4.63s
# 473:	total: 4.17s	remaining: 4.62s
# 474:	total: 4.17s	remaining: 4.61s
# 475:	total: 4.18s	remaining: 4.6s
# 476:	total: 4.19s	remaining: 4.59s
# 477:	total: 4.2s	remaining: 4.58s
# 478:	total: 4.2s	remaining: 4.57s
# 479:	total: 4.21s	remaining: 4.56s
# 480:	total: 4.23s	remaining: 4.56s
# 481:	total: 4.23s	remaining: 4.55s
# 482:	total: 4.24s	remaining: 4.54s
# 483:	total: 4.25s	remaining: 4.53s
# 484:	total: 4.26s	remaining: 4.52s
# 485:	total: 4.26s	remaining: 4.51s
# 486:	total: 4.27s	remaining: 4.5s
# 487:	total: 4.28s	remaining: 4.49s
# 488:	total: 4.28s	remaining: 4.48s
# 489:	total: 4.29s	remaining: 4.47s
# 490:	total: 4.3s	remaining: 4.46s
# 491:	total: 4.32s	remaining: 4.46s
# 492:	total: 4.32s	remaining: 4.45s
# 493:	total: 4.33s	remaining: 4.44s
# 494:	total: 4.34s	remaining: 4.42s
# 495:	total: 4.35s	remaining: 4.42s
# 496:	total: 4.36s	remaining: 4.41s
# 497:	total: 4.37s	remaining: 4.4s
# 498:	total: 4.38s	remaining: 4.39s
# 499:	total: 4.38s	remaining: 4.38s
# 500:	total: 4.39s	remaining: 4.37s
# 501:	total: 4.41s	remaining: 4.37s
# 502:	total: 4.42s	remaining: 4.36s
# 503:	total: 4.42s	remaining: 4.35s
# 504:	total: 4.43s	remaining: 4.34s
# 505:	total: 4.44s	remaining: 4.33s
# 506:	total: 4.44s	remaining: 4.32s
# 507:	total: 4.45s	remaining: 4.31s
# 508:	total: 4.46s	remaining: 4.3s
# 509:	total: 4.46s	remaining: 4.29s
# 510:	total: 4.47s	remaining: 4.28s
# 511:	total: 4.48s	remaining: 4.27s
# 512:	total: 4.5s	remaining: 4.27s
# 513:	total: 4.5s	remaining: 4.26s
# 514:	total: 4.51s	remaining: 4.25s
# 515:	total: 4.52s	remaining: 4.24s
# 516:	total: 4.52s	remaining: 4.23s
# 517:	total: 4.53s	remaining: 4.22s
# 518:	total: 4.54s	remaining: 4.21s
# 519:	total: 4.54s	remaining: 4.2s
# 520:	total: 4.55s	remaining: 4.19s
# 521:	total: 4.56s	remaining: 4.18s
# 522:	total: 4.58s	remaining: 4.18s
# 523:	total: 4.59s	remaining: 4.17s
# 524:	total: 4.6s	remaining: 4.16s
# 525:	total: 4.61s	remaining: 4.15s
# 526:	total: 4.61s	remaining: 4.14s
# 527:	total: 4.62s	remaining: 4.13s
# 528:	total: 4.63s	remaining: 4.12s
# 529:	total: 4.64s	remaining: 4.11s
# 530:	total: 4.64s	remaining: 4.1s
# 531:	total: 4.65s	remaining: 4.09s
# 532:	total: 4.67s	remaining: 4.09s
# 533:	total: 4.68s	remaining: 4.08s
# 534:	total: 4.68s	remaining: 4.07s
# 535:	total: 4.69s	remaining: 4.06s
# 536:	total: 4.7s	remaining: 4.05s
# 537:	total: 4.71s	remaining: 4.04s
# 538:	total: 4.71s	remaining: 4.03s
# 539:	total: 4.72s	remaining: 4.02s
# 540:	total: 4.73s	remaining: 4.01s
# 541:	total: 4.74s	remaining: 4s
# 542:	total: 4.75s	remaining: 4s
# 543:	total: 4.76s	remaining: 3.99s
# 544:	total: 4.77s	remaining: 3.98s
# 545:	total: 4.78s	remaining: 3.97s
# 546:	total: 4.79s	remaining: 3.96s
# 547:	total: 4.79s	remaining: 3.95s
# 548:	total: 4.8s	remaining: 3.94s
# 549:	total: 4.81s	remaining: 3.93s
# 550:	total: 4.82s	remaining: 3.92s
# 551:	total: 4.83s	remaining: 3.92s
# 552:	total: 4.83s	remaining: 3.91s
# 553:	total: 4.85s	remaining: 3.9s
# 554:	total: 4.86s	remaining: 3.9s
# 555:	total: 4.87s	remaining: 3.88s
# 556:	total: 4.87s	remaining: 3.88s
# 557:	total: 4.88s	remaining: 3.87s
# 558:	total: 4.89s	remaining: 3.85s
# 559:	total: 4.89s	remaining: 3.85s
# 560:	total: 4.9s	remaining: 3.83s
# 561:	total: 4.91s	remaining: 3.83s
# 562:	total: 4.92s	remaining: 3.82s
# 563:	total: 4.94s	remaining: 3.82s
# 564:	total: 4.95s	remaining: 3.81s
# 565:	total: 4.96s	remaining: 3.8s
# 566:	total: 4.96s	remaining: 3.79s
# 567:	total: 4.97s	remaining: 3.78s
# 568:	total: 4.98s	remaining: 3.77s
# 569:	total: 4.99s	remaining: 3.76s
# 570:	total: 4.99s	remaining: 3.75s
# 571:	total: 5s	remaining: 3.74s
# 572:	total: 5.01s	remaining: 3.73s
# 573:	total: 5.02s	remaining: 3.73s
# 574:	total: 5.03s	remaining: 3.72s
# 575:	total: 5.04s	remaining: 3.71s
# 576:	total: 5.05s	remaining: 3.7s
# 577:	total: 5.06s	remaining: 3.69s
# 578:	total: 5.07s	remaining: 3.68s
# 579:	total: 5.07s	remaining: 3.67s
# 580:	total: 5.08s	remaining: 3.67s
# 581:	total: 5.09s	remaining: 3.66s
# 582:	total: 5.1s	remaining: 3.65s
# 583:	total: 5.11s	remaining: 3.64s
# 584:	total: 5.11s	remaining: 3.63s
# 585:	total: 5.12s	remaining: 3.62s
# 586:	total: 5.13s	remaining: 3.61s
# 587:	total: 5.13s	remaining: 3.6s
# 588:	total: 5.14s	remaining: 3.59s
# 589:	total: 5.15s	remaining: 3.58s
# 590:	total: 5.16s	remaining: 3.57s
# 591:	total: 5.16s	remaining: 3.56s
# 592:	total: 5.17s	remaining: 3.55s
# 593:	total: 5.18s	remaining: 3.54s
# 594:	total: 5.19s	remaining: 3.53s
# 595:	total: 5.21s	remaining: 3.53s
# 596:	total: 5.21s	remaining: 3.52s
# 597:	total: 5.22s	remaining: 3.51s
# 598:	total: 5.23s	remaining: 3.5s
# 599:	total: 5.23s	remaining: 3.49s
# 600:	total: 5.24s	remaining: 3.48s
# 601:	total: 5.25s	remaining: 3.47s
# 602:	total: 5.26s	remaining: 3.46s
# 603:	total: 5.26s	remaining: 3.45s
# 604:	total: 5.27s	remaining: 3.44s
# 605:	total: 5.3s	remaining: 3.44s
# 606:	total: 5.3s	remaining: 3.43s
# 607:	total: 5.31s	remaining: 3.42s
# 608:	total: 5.32s	remaining: 3.42s
# 609:	total: 5.33s	remaining: 3.4s
# 610:	total: 5.33s	remaining: 3.4s
# 611:	total: 5.34s	remaining: 3.39s
# 612:	total: 5.35s	remaining: 3.38s
# 613:	total: 5.36s	remaining: 3.37s
# 614:	total: 5.36s	remaining: 3.36s
# 615:	total: 5.38s	remaining: 3.35s
# 616:	total: 5.39s	remaining: 3.34s
# 617:	total: 5.39s	remaining: 3.33s
# 618:	total: 5.4s	remaining: 3.32s
# 619:	total: 5.41s	remaining: 3.31s
# 620:	total: 5.42s	remaining: 3.31s
# 621:	total: 5.42s	remaining: 3.3s
# 622:	total: 5.43s	remaining: 3.29s
# 623:	total: 5.44s	remaining: 3.28s
# 624:	total: 5.45s	remaining: 3.27s
# 625:	total: 5.45s	remaining: 3.26s
# 626:	total: 5.47s	remaining: 3.25s
# 627:	total: 5.48s	remaining: 3.25s
# 628:	total: 5.49s	remaining: 3.24s
# 629:	total: 5.49s	remaining: 3.23s
# 630:	total: 5.5s	remaining: 3.22s
# 631:	total: 5.51s	remaining: 3.21s
# 632:	total: 5.51s	remaining: 3.2s
# 633:	total: 5.52s	remaining: 3.19s
# 634:	total: 5.54s	remaining: 3.18s
# 635:	total: 5.54s	remaining: 3.17s
# 636:	total: 5.56s	remaining: 3.17s
# 637:	total: 5.57s	remaining: 3.16s
# 638:	total: 5.57s	remaining: 3.15s
# 639:	total: 5.58s	remaining: 3.14s
# 640:	total: 5.59s	remaining: 3.13s
# 641:	total: 5.59s	remaining: 3.12s
# 642:	total: 5.6s	remaining: 3.11s
# 643:	total: 5.61s	remaining: 3.1s
# 644:	total: 5.62s	remaining: 3.09s
# 645:	total: 5.62s	remaining: 3.08s
# 646:	total: 5.63s	remaining: 3.07s
# 647:	total: 5.65s	remaining: 3.07s
# 648:	total: 5.66s	remaining: 3.06s
# 649:	total: 5.67s	remaining: 3.05s
# 650:	total: 5.67s	remaining: 3.04s
# 651:	total: 5.68s	remaining: 3.03s
# 652:	total: 5.69s	remaining: 3.02s
# 653:	total: 5.69s	remaining: 3.01s
# 654:	total: 5.7s	remaining: 3s
# 655:	total: 5.71s	remaining: 2.99s
# 656:	total: 5.71s	remaining: 2.98s
# 657:	total: 5.72s	remaining: 2.97s
# 658:	total: 5.74s	remaining: 2.97s
# 659:	total: 5.75s	remaining: 2.96s
# 660:	total: 5.75s	remaining: 2.95s
# 661:	total: 5.77s	remaining: 2.94s
# 662:	total: 5.77s	remaining: 2.94s
# 663:	total: 5.78s	remaining: 2.92s
# 664:	total: 5.79s	remaining: 2.92s
# 665:	total: 5.8s	remaining: 2.91s
# 666:	total: 5.8s	remaining: 2.9s
# 667:	total: 5.82s	remaining: 2.89s
# 668:	total: 5.83s	remaining: 2.88s
# 669:	total: 5.84s	remaining: 2.87s
# 670:	total: 5.84s	remaining: 2.87s
# 671:	total: 5.85s	remaining: 2.85s
# 672:	total: 5.86s	remaining: 2.85s
# 673:	total: 5.86s	remaining: 2.84s
# 674:	total: 5.87s	remaining: 2.83s
# 675:	total: 5.88s	remaining: 2.82s
# 676:	total: 5.88s	remaining: 2.81s
# 677:	total: 5.89s	remaining: 2.8s
# 678:	total: 5.91s	remaining: 2.79s
# 679:	total: 5.92s	remaining: 2.78s
# 680:	total: 5.92s	remaining: 2.77s
# 681:	total: 5.93s	remaining: 2.77s
# 682:	total: 5.94s	remaining: 2.76s
# 683:	total: 5.95s	remaining: 2.75s
# 684:	total: 5.95s	remaining: 2.74s
# 685:	total: 5.96s	remaining: 2.73s
# 686:	total: 5.97s	remaining: 2.72s
# 687:	total: 5.98s	remaining: 2.71s
# 688:	total: 5.98s	remaining: 2.7s
# 689:	total: 6.01s	remaining: 2.7s
# 690:	total: 6.02s	remaining: 2.69s
# 691:	total: 6.02s	remaining: 2.68s
# 692:	total: 6.03s	remaining: 2.67s
# 693:	total: 6.04s	remaining: 2.66s
# 694:	total: 6.04s	remaining: 2.65s
# 695:	total: 6.05s	remaining: 2.64s
# 696:	total: 6.06s	remaining: 2.63s
# 697:	total: 6.07s	remaining: 2.62s
# 698:	total: 6.07s	remaining: 2.62s
# 699:	total: 6.09s	remaining: 2.61s
# 700:	total: 6.1s	remaining: 2.6s
# 701:	total: 6.11s	remaining: 2.59s
# 702:	total: 6.12s	remaining: 2.58s
# 703:	total: 6.12s	remaining: 2.57s
# 704:	total: 6.13s	remaining: 2.56s
# 705:	total: 6.14s	remaining: 2.56s
# 706:	total: 6.15s	remaining: 2.55s
# 707:	total: 6.15s	remaining: 2.54s
# 708:	total: 6.16s	remaining: 2.53s
# 709:	total: 6.18s	remaining: 2.52s
# 710:	total: 6.19s	remaining: 2.52s
# 711:	total: 6.19s	remaining: 2.5s
# 712:	total: 6.2s	remaining: 2.5s
# 713:	total: 6.21s	remaining: 2.49s
# 714:	total: 6.22s	remaining: 2.48s
# 715:	total: 6.22s	remaining: 2.47s
# 716:	total: 6.24s	remaining: 2.46s
# 717:	total: 6.24s	remaining: 2.45s
# 718:	total: 6.25s	remaining: 2.44s
# 719:	total: 6.27s	remaining: 2.44s
# 720:	total: 6.28s	remaining: 2.43s
# 721:	total: 6.28s	remaining: 2.42s
# 722:	total: 6.29s	remaining: 2.41s
# 723:	total: 6.3s	remaining: 2.4s
# 724:	total: 6.3s	remaining: 2.39s
# 725:	total: 6.31s	remaining: 2.38s
# 726:	total: 6.32s	remaining: 2.37s
# 727:	total: 6.33s	remaining: 2.36s
# 728:	total: 6.33s	remaining: 2.35s
# 729:	total: 6.34s	remaining: 2.35s
# 730:	total: 6.35s	remaining: 2.34s
# 731:	total: 6.36s	remaining: 2.33s
# 732:	total: 6.36s	remaining: 2.32s
# 733:	total: 6.37s	remaining: 2.31s
# 734:	total: 6.38s	remaining: 2.3s
# 735:	total: 6.39s	remaining: 2.29s
# 736:	total: 6.39s	remaining: 2.28s
# 737:	total: 6.4s	remaining: 2.27s
# 738:	total: 6.41s	remaining: 2.26s
# 739:	total: 6.41s	remaining: 2.25s
# 740:	total: 6.42s	remaining: 2.25s
# 741:	total: 6.43s	remaining: 2.23s
# 742:	total: 6.45s	remaining: 2.23s
# 743:	total: 6.46s	remaining: 2.22s
# 744:	total: 6.47s	remaining: 2.21s
# 745:	total: 6.48s	remaining: 2.21s
# 746:	total: 6.49s	remaining: 2.2s
# 747:	total: 6.49s	remaining: 2.19s
# 748:	total: 6.5s	remaining: 2.18s
# 749:	total: 6.55s	remaining: 2.19s
# 750:	total: 6.56s	remaining: 2.18s
# 751:	total: 6.57s	remaining: 2.17s
# 752:	total: 6.58s	remaining: 2.16s
# 753:	total: 6.59s	remaining: 2.15s
# 754:	total: 6.59s	remaining: 2.14s
# 755:	total: 6.6s	remaining: 2.13s
# 756:	total: 6.61s	remaining: 2.12s
# 757:	total: 6.62s	remaining: 2.11s
# 758:	total: 6.63s	remaining: 2.1s
# 759:	total: 6.64s	remaining: 2.1s
# 760:	total: 6.64s	remaining: 2.09s
# 761:	total: 6.65s	remaining: 2.08s
# 762:	total: 6.66s	remaining: 2.07s
# 763:	total: 6.67s	remaining: 2.06s
# 764:	total: 6.67s	remaining: 2.05s
# 765:	total: 6.68s	remaining: 2.04s
# 766:	total: 6.69s	remaining: 2.03s
# 767:	total: 6.7s	remaining: 2.02s
# 768:	total: 6.73s	remaining: 2.02s
# 769:	total: 6.73s	remaining: 2.01s
# 770:	total: 6.74s	remaining: 2s
# 771:	total: 6.75s	remaining: 1.99s
# 772:	total: 6.75s	remaining: 1.98s
# 773:	total: 6.76s	remaining: 1.97s
# 774:	total: 6.77s	remaining: 1.96s
# 775:	total: 6.78s	remaining: 1.96s
# 776:	total: 6.78s	remaining: 1.95s
# 777:	total: 6.79s	remaining: 1.94s
# 778:	total: 6.81s	remaining: 1.93s
# 779:	total: 6.82s	remaining: 1.92s
# 780:	total: 6.82s	remaining: 1.91s
# 781:	total: 6.83s	remaining: 1.9s
# 782:	total: 6.84s	remaining: 1.89s
# 783:	total: 6.84s	remaining: 1.89s
# 784:	total: 6.85s	remaining: 1.88s
# 785:	total: 6.86s	remaining: 1.87s
# 786:	total: 6.87s	remaining: 1.86s
# 787:	total: 6.88s	remaining: 1.85s
# 788:	total: 6.88s	remaining: 1.84s
# 789:	total: 6.89s	remaining: 1.83s
# 790:	total: 6.9s	remaining: 1.82s
# 791:	total: 6.91s	remaining: 1.81s
# 792:	total: 6.92s	remaining: 1.8s
# 793:	total: 6.92s	remaining: 1.8s
# 794:	total: 6.93s	remaining: 1.79s
# 795:	total: 6.94s	remaining: 1.78s
# 796:	total: 6.95s	remaining: 1.77s
# 797:	total: 6.96s	remaining: 1.76s
# 798:	total: 6.97s	remaining: 1.75s
# 799:	total: 6.99s	remaining: 1.75s
# 800:	total: 7s	remaining: 1.74s
# 801:	total: 7s	remaining: 1.73s
# 802:	total: 7.01s	remaining: 1.72s
# 803:	total: 7.02s	remaining: 1.71s
# 804:	total: 7.02s	remaining: 1.7s
# 805:	total: 7.03s	remaining: 1.69s
# 806:	total: 7.04s	remaining: 1.68s
# 807:	total: 7.05s	remaining: 1.67s
# 808:	total: 7.05s	remaining: 1.67s
# 809:	total: 7.08s	remaining: 1.66s
# 810:	total: 7.08s	remaining: 1.65s
# 811:	total: 7.09s	remaining: 1.64s
# 812:	total: 7.1s	remaining: 1.63s
# 813:	total: 7.1s	remaining: 1.62s
# 814:	total: 7.11s	remaining: 1.61s
# 815:	total: 7.12s	remaining: 1.6s
# 816:	total: 7.13s	remaining: 1.6s
# 817:	total: 7.18s	remaining: 1.6s
# 818:	total: 7.2s	remaining: 1.59s
# 819:	total: 7.2s	remaining: 1.58s
# 820:	total: 7.21s	remaining: 1.57s
# 821:	total: 7.22s	remaining: 1.56s
# 822:	total: 7.22s	remaining: 1.55s
# 823:	total: 7.23s	remaining: 1.54s
# 824:	total: 7.25s	remaining: 1.54s
# 825:	total: 7.26s	remaining: 1.53s
# 826:	total: 7.26s	remaining: 1.52s
# 827:	total: 7.27s	remaining: 1.51s
# 828:	total: 7.28s	remaining: 1.5s
# 829:	total: 7.29s	remaining: 1.49s
# 830:	total: 7.29s	remaining: 1.48s
# 831:	total: 7.3s	remaining: 1.47s
# 832:	total: 7.31s	remaining: 1.47s
# 833:	total: 7.32s	remaining: 1.46s
# 834:	total: 7.32s	remaining: 1.45s
# 835:	total: 7.34s	remaining: 1.44s
# 836:	total: 7.35s	remaining: 1.43s
# 837:	total: 7.36s	remaining: 1.42s
# 838:	total: 7.36s	remaining: 1.41s
# 839:	total: 7.37s	remaining: 1.4s
# 840:	total: 7.38s	remaining: 1.4s
# 841:	total: 7.39s	remaining: 1.39s
# 842:	total: 7.39s	remaining: 1.38s
# 843:	total: 7.4s	remaining: 1.37s
# 844:	total: 7.41s	remaining: 1.36s
# 845:	total: 7.44s	remaining: 1.35s
# 846:	total: 7.45s	remaining: 1.34s
# 847:	total: 7.45s	remaining: 1.33s
# 848:	total: 7.46s	remaining: 1.33s
# 849:	total: 7.47s	remaining: 1.32s
# 850:	total: 7.47s	remaining: 1.31s
# 851:	total: 7.48s	remaining: 1.3s
# 852:	total: 7.49s	remaining: 1.29s
# 853:	total: 7.5s	remaining: 1.28s
# 854:	total: 7.5s	remaining: 1.27s
# 855:	total: 7.52s	remaining: 1.26s
# 856:	total: 7.53s	remaining: 1.26s
# 857:	total: 7.54s	remaining: 1.25s
# 858:	total: 7.54s	remaining: 1.24s
# 859:	total: 7.55s	remaining: 1.23s
# 860:	total: 7.56s	remaining: 1.22s
# 861:	total: 7.57s	remaining: 1.21s
# 862:	total: 7.57s	remaining: 1.2s
# 863:	total: 7.58s	remaining: 1.19s
# 864:	total: 7.59s	remaining: 1.18s
# 865:	total: 7.61s	remaining: 1.18s
# 866:	total: 7.61s	remaining: 1.17s
# 867:	total: 7.62s	remaining: 1.16s
# 868:	total: 7.63s	remaining: 1.15s
# 869:	total: 7.64s	remaining: 1.14s
# 870:	total: 7.64s	remaining: 1.13s
# 871:	total: 7.66s	remaining: 1.12s
# 872:	total: 7.67s	remaining: 1.11s
# 873:	total: 7.67s	remaining: 1.11s
# 874:	total: 7.68s	remaining: 1.1s
# 875:	total: 7.7s	remaining: 1.09s
# 876:	total: 7.71s	remaining: 1.08s
# 877:	total: 7.71s	remaining: 1.07s
# 878:	total: 7.72s	remaining: 1.06s
# 879:	total: 7.73s	remaining: 1.05s
# 880:	total: 7.74s	remaining: 1.04s
# 881:	total: 7.74s	remaining: 1.04s
# 882:	total: 7.75s	remaining: 1.03s
# 883:	total: 7.76s	remaining: 1.02s
# 884:	total: 7.76s	remaining: 1.01s
# 885:	total: 7.79s	remaining: 1s
# 886:	total: 7.79s	remaining: 993ms
# 887:	total: 7.8s	remaining: 984ms
# 888:	total: 7.81s	remaining: 975ms
# 889:	total: 7.82s	remaining: 966ms
# 890:	total: 7.82s	remaining: 957ms
# 891:	total: 7.83s	remaining: 948ms
# 892:	total: 7.83s	remaining: 939ms
# 893:	total: 7.84s	remaining: 930ms
# 894:	total: 7.85s	remaining: 921ms
# 895:	total: 7.86s	remaining: 912ms
# 896:	total: 7.88s	remaining: 904ms
# 897:	total: 7.88s	remaining: 895ms
# 898:	total: 7.9s	remaining: 887ms
# 899:	total: 7.9s	remaining: 878ms
# 900:	total: 7.91s	remaining: 869ms
# 901:	total: 7.92s	remaining: 861ms
# 902:	total: 7.93s	remaining: 852ms
# 903:	total: 7.94s	remaining: 843ms
# 904:	total: 7.94s	remaining: 834ms
# 905:	total: 7.96s	remaining: 826ms
# 906:	total: 7.97s	remaining: 817ms
# 907:	total: 7.98s	remaining: 808ms
# 908:	total: 7.98s	remaining: 799ms
# 909:	total: 7.99s	remaining: 790ms
# 910:	total: 8s	remaining: 781ms
# 911:	total: 8.01s	remaining: 772ms
# 912:	total: 8.01s	remaining: 764ms
# 913:	total: 8.02s	remaining: 755ms
# 914:	total: 8.03s	remaining: 746ms
# 915:	total: 8.04s	remaining: 737ms
# 916:	total: 8.05s	remaining: 729ms
# 917:	total: 8.06s	remaining: 720ms
# 918:	total: 8.07s	remaining: 711ms
# 919:	total: 8.08s	remaining: 702ms
# 920:	total: 8.08s	remaining: 693ms
# 921:	total: 8.09s	remaining: 684ms
# 922:	total: 8.1s	remaining: 675ms
# 923:	total: 8.1s	remaining: 667ms
# 924:	total: 8.11s	remaining: 658ms
# 925:	total: 8.12s	remaining: 649ms
# 926:	total: 8.14s	remaining: 641ms
# 927:	total: 8.15s	remaining: 632ms
# 928:	total: 8.16s	remaining: 624ms
# 929:	total: 8.17s	remaining: 615ms
# 930:	total: 8.17s	remaining: 606ms
# 931:	total: 8.18s	remaining: 597ms
# 932:	total: 8.19s	remaining: 588ms
# 933:	total: 8.2s	remaining: 579ms
# 934:	total: 8.2s	remaining: 570ms
# 935:	total: 8.21s	remaining: 561ms
# 936:	total: 8.23s	remaining: 553ms
# 937:	total: 8.24s	remaining: 544ms
# 938:	total: 8.24s	remaining: 536ms
# 939:	total: 8.25s	remaining: 527ms
# 940:	total: 8.26s	remaining: 518ms
# 941:	total: 8.27s	remaining: 509ms
# 942:	total: 8.27s	remaining: 500ms
# 943:	total: 8.28s	remaining: 491ms
# 944:	total: 8.29s	remaining: 482ms
# 945:	total: 8.29s	remaining: 473ms
# 946:	total: 8.3s	remaining: 465ms
# 947:	total: 8.32s	remaining: 456ms
# 948:	total: 8.33s	remaining: 448ms
# 949:	total: 8.34s	remaining: 439ms
# 950:	total: 8.34s	remaining: 430ms
# 951:	total: 8.35s	remaining: 421ms
# 952:	total: 8.36s	remaining: 412ms
# 953:	total: 8.37s	remaining: 404ms
# 954:	total: 8.38s	remaining: 395ms
# 955:	total: 8.39s	remaining: 386ms
# 956:	total: 8.39s	remaining: 377ms
# 957:	total: 8.41s	remaining: 369ms
# 958:	total: 8.42s	remaining: 360ms
# 959:	total: 8.43s	remaining: 351ms
# 960:	total: 8.43s	remaining: 342ms
# 961:	total: 8.44s	remaining: 333ms
# 962:	total: 8.45s	remaining: 325ms
# 963:	total: 8.46s	remaining: 316ms
# 964:	total: 8.46s	remaining: 307ms
# 965:	total: 8.47s	remaining: 298ms
# 966:	total: 8.48s	remaining: 289ms
# 967:	total: 8.5s	remaining: 281ms
# 968:	total: 8.5s	remaining: 272ms
# 969:	total: 8.51s	remaining: 263ms
# 970:	total: 8.52s	remaining: 254ms
# 971:	total: 8.53s	remaining: 246ms
# 972:	total: 8.53s	remaining: 237ms
# 973:	total: 8.54s	remaining: 228ms
# 974:	total: 8.55s	remaining: 219ms
# 975:	total: 8.56s	remaining: 210ms
# 976:	total: 8.56s	remaining: 202ms
# 977:	total: 8.57s	remaining: 193ms
# 978:	total: 8.58s	remaining: 184ms
# 979:	total: 8.59s	remaining: 175ms
# 980:	total: 8.6s	remaining: 167ms
# 981:	total: 8.61s	remaining: 158ms
# 982:	total: 8.61s	remaining: 149ms
# 983:	total: 8.62s	remaining: 140ms
# 984:	total: 8.63s	remaining: 131ms
# 985:	total: 8.63s	remaining: 123ms
# 986:	total: 8.64s	remaining: 114ms
# 987:	total: 8.65s	remaining: 105ms
# 988:	total: 8.65s	remaining: 96.3ms
# 989:	total: 8.68s	remaining: 87.7ms
# 990:	total: 8.68s	remaining: 78.9ms
# 991:	total: 8.69s	remaining: 70.1ms
# 992:	total: 8.7s	remaining: 61.3ms
# 993:	total: 8.71s	remaining: 52.6ms
# 994:	total: 8.71s	remaining: 43.8ms
# 995:	total: 8.72s	remaining: 35ms
# 996:	total: 8.73s	remaining: 26.3ms
# 997:	total: 8.74s	remaining: 17.5ms
# 998:	total: 8.74s	remaining: 8.75ms
# 999:	total: 8.76s	remaining: 0us

# %%
pred[:, 1]
# Out:
# array([0.53714874, 0.407947  , 0.19134794, ..., 0.38144899, 0.26111715,
#        0.44184495])

# %%
# Submission DataFrame
submission = pd.DataFrame({"Patient_ID": test.Patient_ID,
                          "Health_Camp_ID":test.Health_Camp_ID, 
                          "Outcome":pred[:, 1]})

# %%
submission.to_csv("VotingModel.csv", index = False) #  0.6385

# %%
cd
# Out:
# C:\Users\IT

# %%
X.columns
# Out:
# Index(['Var1', 'Var2', 'Var3', 'Var4', 'Var5', 'Category1', 'Category3',
#        'Registration_Month', 'Registration_Year', 'Registration_Day',
#        'Online_Presence', 'Camp_Duration', 'Int_Days_Diff', 'HC_per_patient',
#        'Patient_Per_HC', 'Patients_Per_Year', 'Patients_Per_Month',
#        'Patients_Per_End_Year', 'Patients_Per_End_Month', 'Categor2'],
#       dtype='object')

# %%
newtest = newtest.loc[:, X.columns]

# %%
X.shape, newtest.shape
# Out:
# ((75278, 20), (35249, 20))

# %%
# Lightgbm
from lightgbm import LGBMClassifier
lgbm = LGBMClassifier(n_estimators = 500, 
                      max_depth = 10, random_state = 42, 
                      learning_rate=0.01, 
                     scale_pos_weight = 3)

# %%
pred_lgbm = lgbm.fit(X, y).predict_proba(newtest)

# %%
# Submission DataFrame
submission = pd.DataFrame({"Patient_ID": test.Patient_ID,
                          "Health_Camp_ID":test.Health_Camp_ID, 
                          "Outcome":pred_lgbm[:, 1]})

submission.to_csv("LGBM_Model.csv", index = False) #  0.6316

# %% [markdown]
# ### RFECV and Cross Validation

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()

from sklearn.feature_selection import RFECV

rfe = RFECV(estimator = dtree, step = 1, 
           min_features_to_select= 5, cv =  5, verbose = 5)

# %%
rfe.fit(X, y)
features = list(rfe.get_feature_names_out())
print(features)
# Out:
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# ['Var1', 'Category1', 'Registration_Month', 'Registration_Day', 'Online_Presence', 'Camp_Duration', 'Int_Days_Diff', 'HC_per_patient', 'Patient_Per_HC']

# %%
features
# Out:
# ['Var1',
#  'Category1',
#  'Registration_Month',
#  'Registration_Day',
#  'Online_Presence',
#  'Camp_Duration',
#  'Int_Days_Diff',
#  'HC_per_patient',
#  'Patient_Per_HC']

# %%
# RFE Features
rfe_input = X.loc[:, features]
rfe_test = newtest.loc[:, features]

# %%
rfe_input.shape, rfe_test.shape
# Out:
# ((75278, 9), (35249, 9))

# %%
lgbm = LGBMClassifier(n_estimators = 500, 
                      max_depth = 10, random_state = 42, 
                      learning_rate=0.01, 
                     scale_pos_weight = 3)

pred_lgbm = lgbm.fit(rfe_input, y).predict_proba(rfe_test)

# Submission DataFrame
submission = pd.DataFrame({"Patient_ID": test.Patient_ID,
                          "Health_Camp_ID":test.Health_Camp_ID, 
                          "Outcome":pred_lgbm[:, 1]})

submission.to_csv("RFE_Model.csv", index = False) #  0.6316

# %% [markdown]
# ### Cross Validation for LGBM

# %%
from sklearn.model_selection import KFold
kfold = KFold(n_splits=5, shuffle = True)
lgbm = LGBMClassifier(n_estimators = 500, 
                      max_depth = 10, random_state = 42, 
                      learning_rate=0.01, 
                     scale_pos_weight = 3)

pred_df = pd.DataFrame()

n = 5
for i in range(n):
    folds = next(kfold.split(X))
    xtrain = X.iloc[folds[0]] # builds xtrain data
    ytrain = y.iloc[folds[0]] # creates y values
    lgbm.fit(xtrain, ytrain)
    pred_df[i] = lgbm.predict_proba(newtest)[:, 1]

# %%
pred_df
# Out:
#               0         1         2         3         4
# 0      0.834854  0.868591  0.862783  0.857990  0.860368
# 1      0.658681  0.625407  0.669577  0.590478  0.648944
# 2      0.387994  0.382216  0.347617  0.331157  0.377994
# 3      0.571716  0.585202  0.617777  0.637673  0.586138
# 4      0.131144  0.131048  0.124423  0.163304  0.114202
# ...         ...       ...       ...       ...       ...
# 35244  0.734100  0.751343  0.733299  0.658999  0.697985
# 35245  0.434850  0.451803  0.550005  0.412618  0.440168
# 35246  0.735216  0.687731  0.664526  0.626814  0.672619
# 35247  0.343776  0.386784  0.380612  0.423357  0.368626
# 35248  0.665380  0.744835  0.712283  0.715302  0.727665
#
# [35249 rows x 5 columns]

# %%
median_prob = pred_df.median(axis = 1)

# %%
# Submission DataFrame
submission = pd.DataFrame({"Patient_ID": test.Patient_ID,
                          "Health_Camp_ID":test.Health_Camp_ID, 
                          "Outcome":median_prob})

submission.to_csv("Median_Prob.csv", index = False) #  0.6316

# %% [markdown]
# #### Summary
#
# * Model Performance drastically gets impacted by the Feature Engineering
# * We saw that LGBM appeared to be the Best Model across for this competition leading at #2 in Public Leaderboard.
# * We saw that Features Selected using RFECV did not work well and we had to discard that model.
#
# * Parameter Tuning of LGBM can take the Model Performance at the whole new level.
#
# * Cross Validation Model for LGBM did a fantastic job earning us couple of brownie points on Public Leaderboard.
#
# * We learnt that Target Variables can be masked in the dataset which can be extracted by studying the Problem Statement meticulously.
